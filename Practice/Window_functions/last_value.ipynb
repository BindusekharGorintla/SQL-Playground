-- %%
with cte as (
select *,
last_value(order_date) over (partition by  department order by order_date asc rows between unbounded preceding and unbounded following) as new_column
 from workspace.practice.order_window
)
select * from cte
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...
