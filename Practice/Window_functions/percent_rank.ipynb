-- %%
with cte as (
select *,
percent_rank() over (partition by department order by amount desc) as new_column
 from workspace.practice.order_window
)
select * from cte
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...
